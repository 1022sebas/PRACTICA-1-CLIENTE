# %%
nombre = input("Ingrese su nombre: ")
print("Hola, " + nombre + "¡Bienvenido a GOOGLE COLAB!")
edad = int (input("Ingrese su edad: "))
edad_en_10_anios = edad + 10
print("En 16 años , tendras", edad_en_10_anios, "años")
# Out:
# Ingrese su nombre: sebas
# Hola, sebas¡Bienvenido a GOOGLE COLAB!
# Ingrese su edad: 16
# En 16 años , tendras 26 años

# %%
from __future__ import division
nombre = "Sebastian Hernandez"
edad = 16
estatura = 1.72
print(" Nombre:", nombre)
print("Edad: ", edad, "años")
print("Estatura:", estatura, "metros")
suma_edad_estatura = edad + estatura
resta_edad_estatura = edad - estatura
multiplicacion_edad_estatura = edad * estatura
division_edad_estatura = edad / estatura

print("suma de edad y estatura:", suma_edad_estatura)
print("resta de edad y estatura:", resta_edad_estatura)
print("multiplicacion de edad y estatura:", multiplicacion_edad_estatura)
print("division de edad y estatura:", division_edad_estatura)
# Out:
#  Nombre: Sebastian Hernandez
# Edad:  16 años
# Estatura: 1.72 metros
# suma de edad y estatura: 17.72
# resta de edad y estatura: 14.28
# multiplicacion de edad y estatura: 27.52
# division de edad y estatura: 9.30232558139535

# %%
pais = "Japon"
capital = "Tokio"
poblacion = 13730000
print("pais:", pais)
print("captal:", capital)
print("poblacion:", poblacion)
numero_ingresado = float(input("ingresa un numero decimal: "))
resultado = numero_ingresado * 2
print("el doble del numero ingresado es:", resultado)
# Out:
# pais: Japon
# captal: Tokio
# poblacion: 13730000
# ingresa un numero decimal: 1022
# el doble del numero ingresado es: 2044.0
